# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Loading essay images
images_folder  = "../data/essay_pictures/"
ext = ".png"

image = cv2.imread(images_folder+"essay_1"+ext)

fig, ax = plt.subplots(1,1, figsize=(20, 10))
ax.imshow(image)
ax.set_axis_off()

# %%
# Out:
# The other value is:  70.0
